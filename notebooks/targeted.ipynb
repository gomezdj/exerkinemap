# %% [markdown]
# ## Differential Expression Analysis for CCC & Downstream Signalling Networks

# %% [markdown]
# Perform DEA at the pseudobulk level to assess differential expression of genes between conditions, then translate the results into deregulated complex-informed ligand-receptor interactions and analyze their connections to downstream signaling events.

# %%
#!pip install decoupler
#!pip install pydeseq2
# !pip install anndata==0.7.8
# Out:
# ...
#   Using cached anndata-0.7.8-py3-none-any.whl (91 kB)
# ...
#   Using cached xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
# ...
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.1
#     Uninstalling xlrd-2.0.1:
#       Successfully uninstalled xlrd-2.0.1
#   Attempting uninstall: anndata
#     Found existing installation: anndata 0.10.9
#     Uninstalling anndata-0.10.9:
#       Successfully uninstalled anndata-0.10.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scanpy 1.10.3 requires anndata>=0.8, but you have anndata 0.7.8 which is incompatible.
# pydeseq2 0.4.12 requires anndata>=0.8.0, but you have anndata 0.7.8 which is incompatible.
# mudata 0.2.4 requires anndata>=0.10.8, but you have anndata 0.7.8 which is incompatible.
# mofapy2 0.7.2 requires anndata>0.8, but you have anndata 0.7.8 which is incompatible.
# ...

# %%
# !pip install numpy
# !pip install pandas
# !pip install scanpy 

# !pip install plotnine
# !pip install liana
# !pip install decoupler
# !pip install omnipath
# Out:
# ...
#   Using cached scanpy-1.10.3-py3-none-any.whl.metadata (9.4 kB)
# ...
#   Using cached get_annotations-0.1.2-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached legacy_api_wrap-1.4-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached session_info-1.0.0-py3-none-any.whl
# ...
#   Using cached umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached stdlib_list-0.11.0-py3-none-any.whl.metadata (3.3 kB)
# ...
# Using cached scanpy-1.10.3-py3-none-any.whl (2.1 MB)
# Using cached legacy_api_wrap-1.4-py3-none-any.whl (15 kB)
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
import numpy as np
import pandas as pd
import scanpy as sc

import plotnine as p9

import liana as li
import decoupler as dc
import omnipath as op

# Import DESeq2
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 7
#       3 import scanpy as sc
#       5 import plotnine as p9
# ----> 7 import liana as li
#       8 import decoupler as dc
#       9 import omnipath as op
#
# File ~/miniconda3/lib/python3.9/site-packages/liana/__init__.py:3
#       1 __version__ = '1.4.0'
# ----> 3 from liana import method as mt, plotting as pl, resource as rs, multi as mu, utils as ut, testing
#       5 # done after everything has been imported (adapted from scanpy)
#       6 import sys
#
# File ~/miniconda3/lib/python3.9/site-packages/liana/method/__init__.py:3
#       1 import numpy as np
# ----> 3 from liana.method.sc._Method import Method, MethodMeta, _show_methods
#       4 from liana.method.sc._rank_aggregate import AggregateClass, _rank_aggregate_meta as aggregate_meta
# ...

# %%
# Obtain TF regulons
net = dc.get_collectri()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Obtain TF regulons
# ----> 2 net = dc.get_collectri()
#
# NameError: name 'dc' is not defined
