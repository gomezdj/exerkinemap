# %% [markdown]
# ## Benchmark liana vs cellchat vs SCENIC.ipynb
#
# Purpose
#
# Benchmark ExerkineMap against
# LIANA
# CellChat
# SCENIC

# %% [markdown]
# ## Workflow
#
# 1️⃣ Run ExerkineMap scoring
# 2️⃣ Run LIANA
# 3️⃣ Run CellChat
# 4️⃣ Compare:
#
# • Recovered LR pairs
# • Spatial consistency
# • Predictive AUROC
# • Runtime

# %% [markdown]
# ## Evaluation Metrics

# %%
from sklearn.metrics import roc_auc_score

# Example comparison
roc_exerkine = roc_auc_score(y_test, preds)
roc_liana = 0.71   # example
roc_cellchat = 0.68

# %% [markdown]
# Also compare:
#
# • Spearman correlation of interaction rankings
# • Overlap of top 50 LR pairs
# • Computational time
#
# This notebook is what reviewers care about.
