# %% [markdown]
# # 13. EXERKINEMAP Benchmarking & Baseline Evaluation
# This notebook evaluates each major component of the EXERKINEMAP architecture against standard baseline models to verify measurable performance improvements across tokenization, language model embeddings, spatial kernels, graph diffusion, and multimodal cell representations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

PROJECT_ROOT = Path('.').resolve().parents[0]
report_path = PROJECT_ROOT / 'results' / 'benchmarking' / 'component_benchmarking_report.csv'

if report_path.exists():
    df_bench = pd.read_csv(report_path)
    display(df_bench)
else:
    print('Benchmarking report not found. Run tests/run_benchmarking.py first.')
